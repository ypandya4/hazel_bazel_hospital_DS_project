# %%
_dict_list = [{"data": {"admission_id": 82679, "patient_id": 81317898, "race": "Caucasian", "gender": "Male", "age": NaN, "weight": "?", "admission_type_code": 3.0, "discharge_disposition_code": 3.0, "admission_source_code": 1, "time_in_hospital": 7, "payer_code": "MC", "medical_specialty": "Family/GeneralPractice", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 44.0, "num_procedures": 1, "num_medications": 13.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 2, "diag_1": "585", "diag_2": "491", "diag_3": "276", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.6, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 83311, "patient_id": 182969604, "race": "Caucasian", "gender": "Female", "age": "[70-80)", "weight": "?", "admission_type_code": 2.0, "discharge_disposition_code": 2.0, "admission_source_code": 7, "time_in_hospital": 2, "payer_code": "MC", "medical_specialty": "Surgery-General", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 39.0, "num_procedures": 3, "num_medications": 13.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 1, "diag_1": "414", "diag_2": "411", "diag_3": "424", "number_diagnoses": 7, "blood_type": "B-", "hemoglobin_level": 14.8, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 84417, "patient_id": 62128908, "race": "Caucasian", "gender": "Female", "age": "[70-80)", "weight": "?", "admission_type_code": 5.0, "discharge_disposition_code": 6.0, "admission_source_code": 1, "time_in_hospital": 3, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 51.0, "num_procedures": 0, "num_medications": 12.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "965", "diag_2": "780", "diag_3": "E850", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 12.9, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "Norm", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 100530, "patient_id": 26755200, "race": "Afro American", "gender": "Male", "age": "[50-60)", "weight": "?", "admission_type_code": 2.0, "discharge_disposition_code": 18.0, "admission_source_code": 2, "time_in_hospital": 6, "payer_code": "?", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Incomplete", "num_lab_procedures": 33.0, "num_procedures": 1, "num_medications": 10.0, "number_outpatient": 1, "number_emergency": 0, "number_inpatient": 3, "diag_1": "250.6", "diag_2": "585", "diag_3": "578", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 14.1, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 81601, "patient_id": 108594486, "race": "European", "gender": "Female", "age": "[80-90)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 3, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Incomplete", "num_lab_procedures": 38.0, "num_procedures": 3, "num_medications": 13.0, "number_outpatient": 1, "number_emergency": 0, "number_inpatient": 0, "diag_1": "578", "diag_2": "285", "diag_3": "403", "number_diagnoses": 9, "blood_type": "AB+", "hemoglobin_level": 13.7, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 84159, "patient_id": 119588058, "race": "AfricanAmerican", "gender": "Female", "age": "[60-70)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 1, "payer_code": "CM", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 8.0, "num_procedures": 0, "num_medications": 7.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "575", "diag_2": "427", "diag_3": "493", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 14.2, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 99843, "patient_id": 210853530, "race": "Other", "gender": "Male", "age": "[70-80)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 4, "time_in_hospital": 1, "payer_code": "?", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 13.0, "num_procedures": 2, "num_medications": 7.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "996", "diag_2": "453", "diag_3": "403", "number_diagnoses": 9, "blood_type": "A+", "hemoglobin_level": 14.5, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 100354, "patient_id": 247047256, "race": "Caucasian", "gender": "Female", "age": "[70-80)", "weight": "?", "admission_type_code": 2.0, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 4, "payer_code": "?", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 41.0, "num_procedures": 2, "num_medications": 13.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "162", "diag_2": "286", "diag_3": "493", "number_diagnoses": 9, "blood_type": "A+", "hemoglobin_level": 14.1, "blood_transfusion": false, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"admission_id": 90078, "patient_id": 77156334, "race": "Caucasian", "gender": "Female", "age": "[40-50)", "weight": "?", "admission_type_code": 3.0, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 2, "payer_code": "OG", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 2.0, "num_procedures": 4, "num_medications": 17.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "626", "diag_2": "998", "diag_3": "285", "number_diagnoses": 9, "blood_type": "A+", "hemoglobin_level": 12.3, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 87808, "patient_id": 91030932, "race": "Caucasian", "gender": "Male", "age": "[40-50)", "weight": "?", "admission_type_code": 3.0, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 3, "payer_code": "?", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Incomplete", "num_lab_procedures": 35.0, "num_procedures": 4, "num_medications": 27.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "428", "diag_2": "425", "diag_3": "496", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.4, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 101181, "patient_id": 84292938, "race": "Caucasian", "gender": "Female", "age": "[60-70)", "weight": "?", "admission_type_code": 2.0, "discharge_disposition_code": 1.0, "admission_source_code": 4, "time_in_hospital": 4, "payer_code": "CP", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 28.0, "num_procedures": 0, "num_medications": 7.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "398", "diag_2": "396", "diag_3": "397", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 14.5, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 98980, "patient_id": 118726416, "race": "Caucasian", "gender": "Female", "age": "[80-90)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 6, "time_in_hospital": 4, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 68.0, "num_procedures": 0, "num_medications": 19.0, "number_outpatient": 0, "number_emergency": 2, "number_inpatient": 0, "diag_1": "276", "diag_2": "599", "diag_3": "780", "number_diagnoses": 7, "blood_type": "A-", "hemoglobin_level": 13.4, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "Norm", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 87832, "patient_id": 85194756, "race": "EURO", "gender": "Male", "age": "[60-70)", "weight": "?", "admission_type_code": 3.0, "discharge_disposition_code": 6.0, "admission_source_code": 1, "time_in_hospital": 6, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": NaN, "num_procedures": 1, "num_medications": 19.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "584", "diag_2": "276", "diag_3": "276", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 16.2, "blood_transfusion": false, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 86463, "patient_id": 47713626, "race": "White", "gender": "Male", "age": "[60-70)", "weight": "?", "admission_type_code": 3.0, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 1, "payer_code": "MC", "medical_specialty": "Cardiology", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 29.0, "num_procedures": 6, "num_medications": 16.0, "number_outpatient": 0, "number_emergency": 1, "number_inpatient": 1, "diag_1": "414", "diag_2": "401", "diag_3": "V45", "number_diagnoses": 8, "blood_type": "O+", "hemoglobin_level": 14.8, "blood_transfusion": true, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 86723, "patient_id": 127711152, "race": "Other", "gender": "Male", "age": "[50-60)", "weight": "?", "admission_type_code": 2.0, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 1, "payer_code": "?", "medical_specialty": "Cardiology", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 4.0, "num_procedures": 2, "num_medications": 7.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "414", "diag_2": "411", "diag_3": "V45", "number_diagnoses": 5, "blood_type": "O+", "hemoglobin_level": 13.6, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"admission_id": 83845, "patient_id": 198993690, "race": "WHITE", "gender": "Female", "age": "[70-80)", "weight": "?", "admission_type_code": 3.0, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 2, "payer_code": "MC", "medical_specialty": "Hospitalist", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 27.0, "num_procedures": 1, "num_medications": 15.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 3, "diag_1": "250.8", "diag_2": "403", "diag_3": "585", "number_diagnoses": 8, "blood_type": "A+", "hemoglobin_level": 14.0, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 82181, "patient_id": 139251006, "race": "Caucasian", "gender": "Male", "age": "[60-70)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 5, "payer_code": "?", "medical_specialty": "InternalMedicine", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 37.0, "num_procedures": 2, "num_medications": 8.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "560", "diag_2": "507", "diag_3": "250", "number_diagnoses": 8, "blood_type": "A+", "hemoglobin_level": 13.8, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 83097, "patient_id": 129126528, "race": "Caucasian", "gender": "Male", "age": NaN, "weight": "?", "admission_type_code": 3.0, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 4, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 31.0, "num_procedures": 0, "num_medications": 18.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "V57", "diag_2": "V45", "diag_3": "250.6", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.2, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 89734, "patient_id": 46442898, "race": "African American", "gender": "Male", "age": "[70-80)", "weight": "?", "admission_type_code": 3.0, "discharge_disposition_code": 3.0, "admission_source_code": 5, "time_in_hospital": 2, "payer_code": "MC", "medical_specialty": "InternalMedicine", "has_prosthesis": false, "complete_vaccination_status": "Incomplete", "num_lab_procedures": 29.0, "num_procedures": 1, "num_medications": 22.0, "number_outpatient": 0, "number_emergency": 2, "number_inpatient": 1, "diag_1": "401", "diag_2": "780", "diag_3": "438", "number_diagnoses": 8, "blood_type": "A+", "hemoglobin_level": 15.7, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 97435, "patient_id": 85164714, "race": "Caucasian", "gender": "Male", "age": "[60-70)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 6.0, "admission_source_code": 7, "time_in_hospital": 7, "payer_code": "BC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 54.0, "num_procedures": 0, "num_medications": 15.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 1, "diag_1": "486", "diag_2": "428", "diag_3": "204", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 13.6, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"admission_id": 92775, "patient_id": 107572680, "race": "Caucasian", "gender": "Female", "age": "[40-50)", "weight": "?", "admission_type_code": NaN, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 2, "payer_code": "CP", "medical_specialty": "InternalMedicine", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 61.0, "num_procedures": 0, "num_medications": 17.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 1, "diag_1": "250.03", "diag_2": "276", "diag_3": "401", "number_diagnoses": 8, "blood_type": "B-", "hemoglobin_level": 13.2, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"admission_id": 95835, "patient_id": 141401304, "race": "Caucasian", "gender": "Male", "age": "[40-50)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 2, "payer_code": "CP", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 20.0, "num_procedures": 6, "num_medications": 10.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "414", "diag_2": "403", "diag_3": "250", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.7, "blood_transfusion": false, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 85838, "patient_id": 83590092, "race": "Caucasian", "gender": "Female", "age": "[50-60)", "weight": "[75-100)", "admission_type_code": 2.0, "discharge_disposition_code": 6.0, "admission_source_code": 1, "time_in_hospital": 5, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 35.0, "num_procedures": 2, "num_medications": 28.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 3, "diag_1": "729", "diag_2": "428", "diag_3": "427", "number_diagnoses": 9, "blood_type": "A+", "hemoglobin_level": 15.0, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"admission_id": 98262, "patient_id": 3061368, "race": "Caucasian", "gender": "Male", "age": "[70-80)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 2, "payer_code": "?", "medical_specialty": "InternalMedicine", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 46.0, "num_procedures": 2, "num_medications": 15.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 5, "diag_1": "428", "diag_2": "491", "diag_3": "596", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.4, "blood_transfusion": true, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"admission_id": 87677, "patient_id": 206681418, "race": "White", "gender": "Male", "age": "[60-70)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 4, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 38.0, "num_procedures": 0, "num_medications": 14.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "403", "diag_2": "276", "diag_3": "585", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.0, "blood_transfusion": false, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"index": 20020, "admission_id": 92775, "patient_id": 107572680, "race": "Caucasian", "gender": "Female", "age": "[40-50)", "weight": "?", "admission_type_code": NaN, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 2, "payer_code": "CP", "medical_specialty": "InternalMedicine", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 61.0, "num_procedures": 0, "num_medications": 17.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 1, "diag_1": "250.03", "diag_2": "276", "diag_3": "401", "number_diagnoses": 8, "blood_type": "B-", "hemoglobin_level": 13.2, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"index": 20021, "admission_id": 95835, "patient_id": 141401304, "race": "Caucasian", "gender": "Male", "age": "[40-50)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 2, "payer_code": "CP", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 20.0, "num_procedures": 6, "num_medications": 10.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "414", "diag_2": "403", "diag_3": "250", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.7, "blood_transfusion": false, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"index": 20022, "admission_id": 85838, "patient_id": 83590092, "race": "Caucasian", "gender": "Female", "age": "[50-60)", "weight": "[75-100)", "admission_type_code": 2.0, "discharge_disposition_code": 6.0, "admission_source_code": 1, "time_in_hospital": 5, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 35.0, "num_procedures": 2, "num_medications": 28.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 3, "diag_1": "729", "diag_2": "428", "diag_3": "427", "number_diagnoses": 9, "blood_type": "A+", "hemoglobin_level": 15.0, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"index": 20023, "admission_id": 98262, "patient_id": 3061368, "race": "Caucasian", "gender": "Male", "age": "[70-80)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 2, "payer_code": "?", "medical_specialty": "InternalMedicine", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 46.0, "num_procedures": 2, "num_medications": 15.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 5, "diag_1": "428", "diag_2": "491", "diag_3": "596", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.4, "blood_transfusion": true, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"index": 20024, "admission_id": 87677, "patient_id": 206681418, "race": "White", "gender": "Male", "age": "[60-70)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 4, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 38.0, "num_procedures": 0, "num_medications": 14.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "403", "diag_2": "276", "diag_3": "585", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.0, "blood_transfusion": false, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"index": 20020, "admission_id": null, "patient_id": 107572680, "race": "Caucasian", "gender": "Female", "age": "[40-50)", "weight": "?", "admission_type_code": NaN, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 2, "payer_code": "CP", "medical_specialty": "InternalMedicine", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 61.0, "num_procedures": 0, "num_medications": 17.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 1, "diag_1": "250.03", "diag_2": "276", "diag_3": "401", "number_diagnoses": 8, "blood_type": "B-", "hemoglobin_level": 13.2, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"index": 20021, "admission_id": null, "patient_id": 141401304, "race": "Caucasian", "gender": "Male", "age": "[40-50)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 2, "payer_code": "CP", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 20.0, "num_procedures": 6, "num_medications": 10.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "414", "diag_2": "403", "diag_3": "250", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.7, "blood_transfusion": false, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"index": 20022, "admission_id": null, "patient_id": 83590092, "race": "Caucasian", "gender": "Female", "age": "[50-60)", "weight": "[75-100)", "admission_type_code": 2.0, "discharge_disposition_code": 6.0, "admission_source_code": 1, "time_in_hospital": 5, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 35.0, "num_procedures": 2, "num_medications": 28.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 3, "diag_1": "729", "diag_2": "428", "diag_3": "427", "number_diagnoses": 9, "blood_type": "A+", "hemoglobin_level": 15.0, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"index": 20023, "admission_id": null, "patient_id": 3061368, "race": "Caucasian", "gender": "Male", "age": "[70-80)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 2, "payer_code": "?", "medical_specialty": "InternalMedicine", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 46.0, "num_procedures": 2, "num_medications": 15.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 5, "diag_1": "428", "diag_2": "491", "diag_3": "596", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.4, "blood_transfusion": true, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"index": 20024, "admission_id": null, "patient_id": 206681418, "race": "White", "gender": "Male", "age": "[60-70)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 4, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 38.0, "num_procedures": 0, "num_medications": 14.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "403", "diag_2": "276", "diag_3": "585", "number_diagnoses": 9, "blood_type": "O+", "hemoglobin_level": 15.0, "blood_transfusion": false, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"index": 20020.0, "admission_id": 92775.0, "patient_id": 107572680.0, "race": "Caucasian", "gender": "Female", "age": null, "weight": "?", "admission_type_code": NaN, "discharge_disposition_code": 1.0, "admission_source_code": 1.0, "time_in_hospital": 2.0, "payer_code": "CP", "medical_specialty": "InternalMedicine", "has_prosthesis": 0.0, "complete_vaccination_status": "Complete", "num_lab_procedures": 61.0, "num_procedures": 0.0, "num_medications": 17.0, "number_outpatient": 0.0, "number_emergency": 0.0, "number_inpatient": 1.0, "diag_1": "250.03", "diag_2": "276", "diag_3": "401", "number_diagnoses": 8.0, "blood_type": "B-", "hemoglobin_level": 13.2, "blood_transfusion": 0.0, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"index": 20021.0, "admission_id": 95835.0, "patient_id": 141401304.0, "race": "Caucasian", "gender": "Male", "age": "[40-50)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7.0, "time_in_hospital": 2.0, "payer_code": "CP", "medical_specialty": "?", "has_prosthesis": 0.0, "complete_vaccination_status": "Complete", "num_lab_procedures": 20.0, "num_procedures": 6.0, "num_medications": 10.0, "number_outpatient": 0.0, "number_emergency": 0.0, "number_inpatient": 0.0, "diag_1": "414", "diag_2": "403", "diag_3": "250", "number_diagnoses": 9.0, "blood_type": "O+", "hemoglobin_level": 15.7, "blood_transfusion": 0.0, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"index": 20022.0, "admission_id": 85838.0, "patient_id": 83590092.0, "race": "Caucasian", "gender": "Female", "age": "[50-60)", "weight": "[75-100)", "admission_type_code": 2.0, "discharge_disposition_code": 6.0, "admission_source_code": 1.0, "time_in_hospital": 5.0, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": 0.0, "complete_vaccination_status": "Complete", "num_lab_procedures": 35.0, "num_procedures": 2.0, "num_medications": 28.0, "number_outpatient": 0.0, "number_emergency": 0.0, "number_inpatient": 3.0, "diag_1": "729", "diag_2": "428", "diag_3": "427", "number_diagnoses": 9.0, "blood_type": "A+", "hemoglobin_level": 15.0, "blood_transfusion": 0.0, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"index": 20023.0, "admission_id": 98262.0, "patient_id": 3061368.0, "race": "Caucasian", "gender": "Male", "age": "[70-80)", "weight": "?", "admission_type_code": NaN, "discharge_disposition_code": 1.0, "admission_source_code": 7.0, "time_in_hospital": 2.0, "payer_code": "?", "medical_specialty": "InternalMedicine", "has_prosthesis": 0.0, "complete_vaccination_status": "Complete", "num_lab_procedures": 46.0, "num_procedures": 2.0, "num_medications": 15.0, "number_outpatient": 0.0, "number_emergency": 0.0, "number_inpatient": 5.0, "diag_1": "428", "diag_2": "491", "diag_3": "596", "number_diagnoses": 9.0, "blood_type": "O+", "hemoglobin_level": 15.4, "blood_transfusion": 1.0, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"index": NaN, "admission_id": NaN, "patient_id": NaN, "race": null, "gender": null, "age": null, "weight": null, "admission_type_code": NaN, "discharge_disposition_code": NaN, "admission_source_code": NaN, "time_in_hospital": NaN, "payer_code": null, "medical_specialty": null, "has_prosthesis": NaN, "complete_vaccination_status": null, "num_lab_procedures": NaN, "num_procedures": NaN, "num_medications": NaN, "number_outpatient": NaN, "number_emergency": NaN, "number_inpatient": NaN, "diag_1": null, "diag_2": null, "diag_3": null, "number_diagnoses": NaN, "blood_type": null, "hemoglobin_level": NaN, "blood_transfusion": NaN, "max_glu_serum": null, "A1Cresult": null, "diuretics": null, "insulin": null, "change": null, "diabetesMed": null}, "outcome": false}, {"data": {"index": 20020, "admission_id": 92775, "patient_id": 107572680, "race": "Caucasian", "gender": "Female", "age": "[40-50)", "weight": "?", "admission_type_code": NaN, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 2, "payer_code": "CP", "medical_specialty": "InternalMedicine", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 61.0, "num_procedures": 0, "num_medications": 17.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 1, "diag_1": "250.03", "diag_2": "276", "diag_3": "401", "number_diagnoses": 8.0, "blood_type": "B-", "hemoglobin_level": 13.2, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"index": 20021, "admission_id": 95835, "patient_id": 141401304, "race": "Caucasian", "gender": "Male", "age": "[40-50)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 2, "payer_code": "CP", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 20.0, "num_procedures": 6, "num_medications": 10.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "414", "diag_2": "403", "diag_3": "250", "number_diagnoses": 9.0, "blood_type": "O+", "hemoglobin_level": 15.7, "blood_transfusion": false, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "No", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"index": 20022, "admission_id": 85838, "patient_id": 83590092, "race": "Caucasian", "gender": "Female", "age": "[50-60)", "weight": "[75-100)", "admission_type_code": 2.0, "discharge_disposition_code": 6.0, "admission_source_code": 1, "time_in_hospital": 5, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 35.0, "num_procedures": 2, "num_medications": 28.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 3, "diag_1": "729", "diag_2": "428", "diag_3": "427", "number_diagnoses": 9.0, "blood_type": "A+", "hemoglobin_level": 15.0, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}, "outcome": true}, {"data": {"index": 20023, "admission_id": 98262, "patient_id": 3061368, "race": "Caucasian", "gender": "Male", "age": "[70-80)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 2, "payer_code": "?", "medical_specialty": "InternalMedicine", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 46.0, "num_procedures": 2, "num_medications": 15.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 5, "diag_1": "428", "diag_2": "491", "diag_3": "596", "number_diagnoses": 9.0, "blood_type": "O+", "hemoglobin_level": 15.4, "blood_transfusion": true, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "Yes", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}, {"data": {"index": 20024, "admission_id": 87677, "patient_id": 206681418, "race": "White", "gender": "Male", "age": "[60-70)", "weight": "?", "admission_type_code": 1.0, "discharge_disposition_code": 1.0, "admission_source_code": 7, "time_in_hospital": 4, "payer_code": "MC", "medical_specialty": "?", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 38.0, "num_procedures": 0, "num_medications": 14.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 0, "diag_1": "403", "diag_2": "276", "diag_3": "585", "number_diagnoses": 9.0, "blood_type": "O+", "hemoglobin_level": 15.0, "blood_transfusion": false, "max_glu_serum": "NONE", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "Ch", "diabetesMed": "Yes"}, "outcome": true}]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9ede3477cc97> in <module>
# ...
